# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, random_split
from torchvision import transforms
from torchvision.datasets import ImageFolder
import torchvision.models as models
import timm
import cupy

# %%
# Check if GPU is available
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
print(f'Using device: {device}')
# Out:
# Using device: cuda

# %%
# Define data transformations
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# %%
# Define path to your training data
train_data_path = 'AugmentedAlzheimerDataset'
# Load dataset using ImageFolder and split into train and validation
train_dataset = ImageFolder(root=train_data_path, transform=transform)

# %%
pip install -U ultralytics
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.2.49-py3-none-any.whl.metadata (41 kB)
#      ---------------------------------------- 0.0/41.2 kB ? eta -:--:--
#      --------- ------------------------------ 10.2/41.2 kB ? eta -:--:--
#      ---------------------------- --------- 30.7/41.2 kB 330.3 kB/s eta 0:00:01
#      -------------------------------------- 41.2/41.2 kB 329.5 kB/s eta 0:00:00
# Requirement already satisfied: numpy<2.0.0,>=1.23.0 in c:\users\sushant mittal\miniconda3\envs\env\lib\site-packages (from ultralytics) (1.26.3)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\users\sushant mittal\miniconda3\envs\env\lib\site-packages (from ultralytics) (3.8.0)
# Requirement already satisfied: opencv-python>=4.6.0 in c:\users\sushant mittal\miniconda3\envs\env\lib\site-packages (from ultralytics) (4.10.0.84)
# Requirement already satisfied: pillow>=7.1.2 in c:\users\sushant mittal\miniconda3\envs\env\lib\site-packages (from ultralytics) (10.2.0)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\sushant mittal\miniconda3\envs\env\lib\site-packages (from ultralytics) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in c:\users\sushant mittal\miniconda3\envs\env\lib\site-packages (from ultralytics) (2.31.0)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\sushant mittal\miniconda3\envs\env\lib\site-packages (from ultralytics) (1.11.4)
# Requirement already satisfied: torch>=1.8.0 in c:\users\sushant mittal\miniconda3\envs\env\lib\site-packages (from ultralytics) (2.3.1+cu118)
# Requirement already satisfied: torchvision>=0.9.0 in c:\users\sushant mittal\miniconda3\envs\env\lib\site-packages (from ultralytics) (0.18.1+cu118)
# Requirement already satisfied: tqdm>=4.64.0 in c:\users\sushant mittal\miniconda3\envs\env\lib\site-packages (from ultralytics) (4.66.4)
# Requirement already satisfied: psutil in c:\users\sushant mittal\miniconda3\envs\env\lib\site-packages (from ultralytics) (5.9.0)
# Collecting py-cpuinfo (from ultralytics)
#   Downloading py_cpuinfo-9.0.0-py3-none-any.whl.metadata (794 bytes)
# Requirement already satisfied: pandas>=1.1.4 in c:\users\sushant mittal\miniconda3\envs\env\lib\site-packages (from ultralytics) (2.1.4)
# Requirement already satisfied: seaborn>=0.11.0 in c:\users\sushant mittal\miniconda3\envs\env\lib\site-packages (from ultralytics) (0.13.2)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics)
#   Downloading ultralytics_thop-2.0.0-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\sushant mittal\miniconda3\envs\env\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\sushant mittal\miniconda3\envs\env\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\sushant mittal\miniconda3\envs\env\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\sushant mittal\miniconda3\envs\env\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\sushant mittal\miniconda3\envs\env\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (23.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\sushant mittal\miniconda3\envs\env\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\sushant mittal\miniconda3\envs\env\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sushant mittal\miniconda3\envs\env\lib\site-packages (from pandas>=1.1.4->ultralytics) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\sushant mittal\miniconda3\envs\env\lib\site-packages (from pandas>=1.1.4->ultralytics) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sushant mittal\miniconda3\envs\env\lib\site-packages (from requests>=2.23.0->ultralytics) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sushant mittal\miniconda3\envs\env\lib\site-packages (from requests>=2.23.0->ultralytics) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sushant mittal\miniconda3\envs\env\lib\site-packages (from requests>=2.23.0->ultralytics) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sushant mittal\miniconda3\envs\env\lib\site-packages (from requests>=2.23.0->ultralytics) (2024.2.2)
# Requirement already satisfied: filelock in c:\users\sushant mittal\miniconda3\envs\env\lib\site-packages (from torch>=1.8.0->ultralytics) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\sushant mittal\miniconda3\envs\env\lib\site-packages (from torch>=1.8.0->ultralytics) (4.9.0)
# Requirement already satisfied: sympy in c:\users\sushant mittal\miniconda3\envs\env\lib\site-packages (from torch>=1.8.0->ultralytics) (1.12)
# Requirement already satisfied: networkx in c:\users\sushant mittal\miniconda3\envs\env\lib\site-packages (from torch>=1.8.0->ultralytics) (3.2.1)
# Requirement already satisfied: jinja2 in c:\users\sushant mittal\miniconda3\envs\env\lib\site-packages (from torch>=1.8.0->ultralytics) (3.1.3)
# Requirement already satisfied: fsspec in c:\users\sushant mittal\miniconda3\envs\env\lib\site-packages (from torch>=1.8.0->ultralytics) (2024.2.0)
# Requirement already satisfied: mkl<=2021.4.0,>=2021.1.1 in c:\users\sushant mittal\miniconda3\envs\env\lib\site-packages (from torch>=1.8.0->ultralytics) (2021.4.0)
# Requirement already satisfied: colorama in c:\users\sushant mittal\miniconda3\envs\env\lib\site-packages (from tqdm>=4.64.0->ultralytics) (0.4.6)
# Requirement already satisfied: intel-openmp==2021.* in c:\users\sushant mittal\miniconda3\envs\env\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch>=1.8.0->ultralytics) (2021.4.0)
# Requirement already satisfied: tbb==2021.* in c:\users\sushant mittal\miniconda3\envs\env\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch>=1.8.0->ultralytics) (2021.11.0)
# Requirement already satisfied: six>=1.5 in c:\users\sushant mittal\miniconda3\envs\env\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\sushant mittal\miniconda3\envs\env\lib\site-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in c:\users\sushant mittal\miniconda3\envs\env\lib\site-packages (from sympy->torch>=1.8.0->ultralytics) (1.3.0)
# Downloading ultralytics-8.2.49-py3-none-any.whl (796 kB)
#    ---------------------------------------- 0.0/796.9 kB ? eta -:--:--
#    ------------ --------------------------- 256.0/796.9 kB 7.9 MB/s eta 0:00:01
#    --------------------------------------- 796.9/796.9 kB 12.5 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.0-py3-none-any.whl (25 kB)
# Downloading py_cpuinfo-9.0.0-py3-none-any.whl (22 kB)
# Installing collected packages: py-cpuinfo, ultralytics-thop, ultralytics
# Successfully installed py-cpuinfo-9.0.0 ultralytics-8.2.49 ultralytics-thop-2.0.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# Assuming you want to split 80% for training and 20% for validation
train_size = int(0.8 * len(train_dataset))
val_size = int(0.1*len(train_dataset))
test_size = len(train_dataset) - train_size - val_size

train_dataset, val_dataset, test_dataset = random_split(train_dataset, [train_size, val_size, test_size])

# %%
# Create data loaders
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# %%
pip install yolov5
# Out:
# Collecting yolov5
#   Downloading yolov5-7.0.13-py37.py38.py39.py310-none-any.whl.metadata (10 kB)
# Collecting gitpython>=3.1.30 (from yolov5)
#   Using cached GitPython-3.1.43-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: matplotlib>=3.3 in c:\users\sushant mittal\miniconda3\envs\env\lib\site-packages (from yolov5) (3.8.0)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\sushant mittal\miniconda3\envs\env\lib\site-packages (from yolov5) (1.26.3)
# Requirement already satisfied: opencv-python>=4.1.1 in c:\users\sushant mittal\miniconda3\envs\env\lib\site-packages (from yolov5) (4.10.0.84)
# Requirement already satisfied: Pillow>=7.1.2 in c:\users\sushant mittal\miniconda3\envs\env\lib\site-packages (from yolov5) (10.2.0)
# Requirement already satisfied: psutil in c:\users\sushant mittal\miniconda3\envs\env\lib\site-packages (from yolov5) (5.9.0)
# Requirement already satisfied: PyYAML>=5.3.1 in c:\users\sushant mittal\miniconda3\envs\env\lib\site-packages (from yolov5) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in c:\users\sushant mittal\miniconda3\envs\env\lib\site-packages (from yolov5) (2.31.0)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\sushant mittal\miniconda3\envs\env\lib\site-packages (from yolov5) (1.11.4)
# Collecting thop>=0.1.1 (from yolov5)
#   Downloading thop-0.1.1.post2209072238-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: torch>=1.7.0 in c:\users\sushant mittal\miniconda3\envs\env\lib\site-packages (from yolov5) (2.3.1+cu118)
# Requirement already satisfied: torchvision>=0.8.1 in c:\users\sushant mittal\miniconda3\envs\env\lib\site-packages (from yolov5) (0.18.1+cu118)
# Requirement already satisfied: tqdm>=4.64.0 in c:\users\sushant mittal\miniconda3\envs\env\lib\site-packages (from yolov5) (4.66.4)
# Requirement already satisfied: ultralytics>=8.0.100 in c:\users\sushant mittal\miniconda3\envs\env\lib\site-packages (from yolov5) (8.2.49)
# Requirement already satisfied: tensorboard>=2.4.1 in c:\users\sushant mittal\miniconda3\envs\env\lib\site-packages (from yolov5) (2.16.2)
# Requirement already satisfied: pandas>=1.1.4 in c:\users\sushant mittal\miniconda3\envs\env\lib\site-packages (from yolov5) (2.1.4)
# Requirement already satisfied: seaborn>=0.11.0 in c:\users\sushant mittal\miniconda3\envs\env\lib\site-packages (from yolov5) (0.13.2)
# Requirement already satisfied: setuptools>=65.5.1 in c:\users\sushant mittal\miniconda3\envs\env\lib\site-packages (from yolov5) (68.2.2)
# Collecting fire (from yolov5)
#   Downloading fire-0.6.0.tar.gz (88 kB)
#      ---------------------------------------- 0.0/88.4 kB ? eta -:--:--
#      ---- ----------------------------------- 10.2/88.4 kB ? eta -:--:--
#      ------------------------------------- -- 81.9/88.4 kB 1.5 MB/s eta 0:00:01
#      ---------------------------------------- 88.4/88.4 kB 1.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting boto3>=1.19.1 (from yolov5)
#   Downloading boto3-1.34.139-py3-none-any.whl.metadata (6.6 kB)
# Collecting sahi>=0.11.10 (from yolov5)
#   Downloading sahi-0.11.16-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: huggingface-hub>=0.12.0 in c:\users\sushant mittal\miniconda3\envs\env\lib\site-packages (from yolov5) (0.23.4)
# Collecting roboflow>=0.2.29 (from yolov5)
#   Downloading roboflow-1.1.34-py3-none-any.whl.metadata (9.5 kB)
# Collecting botocore<1.35.0,>=1.34.139 (from boto3>=1.19.1->yolov5)
#   Downloading botocore-1.34.139-py3-none-any.whl.metadata (5.7 kB)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3>=1.19.1->yolov5)
#   Downloading jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting s3transfer<0.11.0,>=0.10.0 (from boto3>=1.19.1->yolov5)
#   Downloading s3transfer-0.10.2-py3-none-any.whl.metadata (1.7 kB)
# Collecting gitdb<5,>=4.0.1 (from gitpython>=3.1.30->yolov5)
#   Using cached gitdb-4.0.11-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: filelock in c:\users\sushant mittal\miniconda3\envs\env\lib\site-packages (from huggingface-hub>=0.12.0->yolov5) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\sushant mittal\miniconda3\envs\env\lib\site-packages (from huggingface-hub>=0.12.0->yolov5) (2024.2.0)
# Requirement already satisfied: packaging>=20.9 in c:\users\sushant mittal\miniconda3\envs\env\lib\site-packages (from huggingface-hub>=0.12.0->yolov5) (23.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\sushant mittal\miniconda3\envs\env\lib\site-packages (from huggingface-hub>=0.12.0->yolov5) (4.9.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\sushant mittal\miniconda3\envs\env\lib\site-packages (from matplotlib>=3.3->yolov5) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\sushant mittal\miniconda3\envs\env\lib\site-packages (from matplotlib>=3.3->yolov5) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\sushant mittal\miniconda3\envs\env\lib\site-packages (from matplotlib>=3.3->yolov5) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\sushant mittal\miniconda3\envs\env\lib\site-packages (from matplotlib>=3.3->yolov5) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\sushant mittal\miniconda3\envs\env\lib\site-packages (from matplotlib>=3.3->yolov5) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\sushant mittal\miniconda3\envs\env\lib\site-packages (from matplotlib>=3.3->yolov5) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sushant mittal\miniconda3\envs\env\lib\site-packages (from pandas>=1.1.4->yolov5) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\sushant mittal\miniconda3\envs\env\lib\site-packages (from pandas>=1.1.4->yolov5) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sushant mittal\miniconda3\envs\env\lib\site-packages (from requests>=2.23.0->yolov5) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sushant mittal\miniconda3\envs\env\lib\site-packages (from requests>=2.23.0->yolov5) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sushant mittal\miniconda3\envs\env\lib\site-packages (from requests>=2.23.0->yolov5) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sushant mittal\miniconda3\envs\env\lib\site-packages (from requests>=2.23.0->yolov5) (2024.2.2)
# Collecting chardet==4.0.0 (from roboflow>=0.2.29->yolov5)
#   Downloading chardet-4.0.0-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting idna<4,>=2.5 (from requests>=2.23.0->yolov5)
#   Downloading idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# Collecting opencv-python-headless==4.10.0.84 (from roboflow>=0.2.29->yolov5)
#   Downloading opencv_python_headless-4.10.0.84-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Collecting python-dotenv (from roboflow>=0.2.29->yolov5)
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: six in c:\users\sushant mittal\miniconda3\envs\env\lib\site-packages (from roboflow>=0.2.29->yolov5) (1.16.0)
# Collecting requests-toolbelt (from roboflow>=0.2.29->yolov5)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Collecting python-magic (from roboflow>=0.2.29->yolov5)
#   Downloading python_magic-0.4.27-py2.py3-none-any.whl.metadata (5.8 kB)
# Collecting opencv-python>=4.1.1 (from yolov5)
#   Downloading opencv_python-4.8.1.78-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Collecting shapely>=1.8.0 (from sahi>=0.11.10->yolov5)
#   Downloading shapely-2.0.4-cp310-cp310-win_amd64.whl.metadata (7.2 kB)
# Collecting pybboxes==0.1.6 (from sahi>=0.11.10->yolov5)
#   Downloading pybboxes-0.1.6-py3-none-any.whl.metadata (9.9 kB)
# Collecting terminaltables (from sahi>=0.11.10->yolov5)
#   Downloading terminaltables-3.1.10-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting click (from sahi>=0.11.10->yolov5)
#   Using cached click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: absl-py>=0.4 in c:\users\sushant mittal\miniconda3\envs\env\lib\site-packages (from tensorboard>=2.4.1->yolov5) (2.1.0)
# Requirement already satisfied: grpcio>=1.48.2 in c:\users\sushant mittal\miniconda3\envs\env\lib\site-packages (from tensorboard>=2.4.1->yolov5) (1.64.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\sushant mittal\miniconda3\envs\env\lib\site-packages (from tensorboard>=2.4.1->yolov5) (3.6)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in c:\users\sushant mittal\miniconda3\envs\env\lib\site-packages (from tensorboard>=2.4.1->yolov5) (4.25.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\sushant mittal\miniconda3\envs\env\lib\site-packages (from tensorboard>=2.4.1->yolov5) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\sushant mittal\miniconda3\envs\env\lib\site-packages (from tensorboard>=2.4.1->yolov5) (3.0.3)
# Requirement already satisfied: sympy in c:\users\sushant mittal\miniconda3\envs\env\lib\site-packages (from torch>=1.7.0->yolov5) (1.12)
# Requirement already satisfied: networkx in c:\users\sushant mittal\miniconda3\envs\env\lib\site-packages (from torch>=1.7.0->yolov5) (3.2.1)
# Requirement already satisfied: jinja2 in c:\users\sushant mittal\miniconda3\envs\env\lib\site-packages (from torch>=1.7.0->yolov5) (3.1.3)
# Requirement already satisfied: mkl<=2021.4.0,>=2021.1.1 in c:\users\sushant mittal\miniconda3\envs\env\lib\site-packages (from torch>=1.7.0->yolov5) (2021.4.0)
# Requirement already satisfied: colorama in c:\users\sushant mittal\miniconda3\envs\env\lib\site-packages (from tqdm>=4.64.0->yolov5) (0.4.6)
# Requirement already satisfied: py-cpuinfo in c:\users\sushant mittal\miniconda3\envs\env\lib\site-packages (from ultralytics>=8.0.100->yolov5) (9.0.0)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in c:\users\sushant mittal\miniconda3\envs\env\lib\site-packages (from ultralytics>=8.0.100->yolov5) (2.0.0)
# Requirement already satisfied: termcolor in c:\users\sushant mittal\miniconda3\envs\env\lib\site-packages (from fire->yolov5) (2.4.0)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython>=3.1.30->yolov5)
#   Using cached smmap-5.0.1-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: intel-openmp==2021.* in c:\users\sushant mittal\miniconda3\envs\env\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch>=1.7.0->yolov5) (2021.4.0)
# Requirement already satisfied: tbb==2021.* in c:\users\sushant mittal\miniconda3\envs\env\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch>=1.7.0->yolov5) (2021.11.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\sushant mittal\miniconda3\envs\env\lib\site-packages (from werkzeug>=1.0.1->tensorboard>=2.4.1->yolov5) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in c:\users\sushant mittal\miniconda3\envs\env\lib\site-packages (from sympy->torch>=1.7.0->yolov5) (1.3.0)
# Downloading yolov5-7.0.13-py37.py38.py39.py310-none-any.whl (953 kB)
#    ---------------------------------------- 0.0/953.4 kB ? eta -:--:--
#    - -------------------------------------- 41.0/953.4 kB ? eta -:--:--
#    ------- -------------------------------- 174.1/953.4 kB 2.1 MB/s eta 0:00:01
#    ----------- ---------------------------- 276.5/953.4 kB 1.9 MB/s eta 0:00:01
#    ---------------- ----------------------- 389.1/953.4 kB 2.2 MB/s eta 0:00:01
#    ---------------------- ----------------- 532.5/953.4 kB 2.4 MB/s eta 0:00:01
#    ----------------------------- ---------- 696.3/953.4 kB 2.4 MB/s eta 0:00:01
#    ---------------------------------- ----- 829.4/953.4 kB 2.6 MB/s eta 0:00:01
#    ---------------------------------- ----- 829.4/953.4 kB 2.6 MB/s eta 0:00:01
#    ---------------------------------------  952.3/953.4 kB 2.4 MB/s eta 0:00:01
#    ---------------------------------------- 953.4/953.4 kB 2.2 MB/s eta 0:00:00
# Downloading boto3-1.34.139-py3-none-any.whl (139 kB)
#    ---------------------------------------- 0.0/139.2 kB ? eta -:--:--
#    -------------------------------- ------- 112.6/139.2 kB 3.3 MB/s eta 0:00:01
#    ---------------------------------------- 139.2/139.2 kB 2.1 MB/s eta 0:00:00
# Using cached GitPython-3.1.43-py3-none-any.whl (207 kB)
# Downloading roboflow-1.1.34-py3-none-any.whl (76 kB)
#    ---------------------------------------- 0.0/76.2 kB ? eta -:--:--
#    ---------------------------------------- 76.2/76.2 kB 4.4 MB/s eta 0:00:00
# Downloading chardet-4.0.0-py2.py3-none-any.whl (178 kB)
#    ---------------------------------------- 0.0/178.7 kB ? eta -:--:--
#    ---------------------------------- ----- 153.6/178.7 kB 4.5 MB/s eta 0:00:01
#    ---------------------------------------- 178.7/178.7 kB 3.6 MB/s eta 0:00:00
# Downloading idna-3.7-py3-none-any.whl (66 kB)
#    ---------------------------------------- 0.0/66.8 kB ? eta -:--:--
#    ---------------------------------------- 66.8/66.8 kB 3.5 MB/s eta 0:00:00
# Downloading opencv_python_headless-4.10.0.84-cp37-abi3-win_amd64.whl (38.8 MB)
#    ---------------------------------------- 0.0/38.8 MB ? eta -:--:--
#    ---------------------------------------- 0.2/38.8 MB 5.0 MB/s eta 0:00:08
#    ---------------------------------------- 0.3/38.8 MB 3.5 MB/s eta 0:00:11
#    ---------------------------------------- 0.4/38.8 MB 3.7 MB/s eta 0:00:11
#     --------------------------------------- 0.5/38.8 MB 3.4 MB/s eta 0:00:12
#     --------------------------------------- 0.7/38.8 MB 3.1 MB/s eta 0:00:13
#     --------------------------------------- 0.8/38.8 MB 3.1 MB/s eta 0:00:13
#    - -------------------------------------- 1.0/38.8 MB 3.3 MB/s eta 0:00:12
#    - -------------------------------------- 1.1/38.8 MB 3.3 MB/s eta 0:00:12
#    - -------------------------------------- 1.3/38.8 MB 3.3 MB/s eta 0:00:12
#    - -------------------------------------- 1.4/38.8 MB 3.3 MB/s eta 0:00:12
#    - -------------------------------------- 1.6/38.8 MB 3.3 MB/s eta 0:00:12
#    - -------------------------------------- 1.8/38.8 MB 3.3 MB/s eta 0:00:12
#    - -------------------------------------- 1.9/38.8 MB 3.4 MB/s eta 0:00:11
#    -- ------------------------------------- 2.1/38.8 MB 3.4 MB/s eta 0:00:11
#    -- ------------------------------------- 2.3/38.8 MB 3.3 MB/s eta 0:00:11
#    -- ------------------------------------- 2.5/38.8 MB 3.4 MB/s eta 0:00:11
#    -- ------------------------------------- 2.6/38.8 MB 3.5 MB/s eta 0:00:11
#    -- ------------------------------------- 2.9/38.8 MB 3.5 MB/s eta 0:00:11
#    --- ------------------------------------ 3.0/38.8 MB 3.5 MB/s eta 0:00:11
#    --- ------------------------------------ 3.2/38.8 MB 3.6 MB/s eta 0:00:10
#    --- ------------------------------------ 3.5/38.8 MB 3.6 MB/s eta 0:00:10
#    --- ------------------------------------ 3.5/38.8 MB 3.7 MB/s eta 0:00:10
#    --- ------------------------------------ 3.6/38.8 MB 3.4 MB/s eta 0:00:11
#    ---- ----------------------------------- 3.9/38.8 MB 3.5 MB/s eta 0:00:10
#    ---- ----------------------------------- 4.0/38.8 MB 3.5 MB/s eta 0:00:10
#    ---- ----------------------------------- 4.3/38.8 MB 3.6 MB/s eta 0:00:10
#    ---- ----------------------------------- 4.5/38.8 MB 3.7 MB/s eta 0:00:10
#    ---- ----------------------------------- 4.7/38.8 MB 3.7 MB/s eta 0:00:10
#    ----- ---------------------------------- 5.0/38.8 MB 3.8 MB/s eta 0:00:09
#    ----- ---------------------------------- 5.2/38.8 MB 3.8 MB/s eta 0:00:09
#    ----- ---------------------------------- 5.5/38.8 MB 3.9 MB/s eta 0:00:09
#    ----- ---------------------------------- 5.7/38.8 MB 3.9 MB/s eta 0:00:09
#    ----- ---------------------------------- 5.7/38.8 MB 3.9 MB/s eta 0:00:09
#    ----- ---------------------------------- 5.7/38.8 MB 3.9 MB/s eta 0:00:09
#    ----- ---------------------------------- 5.8/38.8 MB 3.7 MB/s eta 0:00:09
#    ----- ---------------------------------- 5.8/38.8 MB 3.7 MB/s eta 0:00:09
#    ----- ---------------------------------- 5.8/38.8 MB 3.7 MB/s eta 0:00:09
#    ----- ---------------------------------- 5.8/38.8 MB 3.3 MB/s eta 0:00:10
#    ------ --------------------------------- 5.8/38.8 MB 3.3 MB/s eta 0:00:10
#    ------ --------------------------------- 5.8/38.8 MB 3.3 MB/s eta 0:00:10
#    ------ --------------------------------- 5.8/38.8 MB 3.3 MB/s eta 0:00:10
#    ------ --------------------------------- 5.9/38.8 MB 3.1 MB/s eta 0:00:11
#    ------ --------------------------------- 5.9/38.8 MB 3.1 MB/s eta 0:00:11
#    ------ --------------------------------- 5.9/38.8 MB 3.1 MB/s eta 0:00:11
#    ------ --------------------------------- 5.9/38.8 MB 3.1 MB/s eta 0:00:11
#    ------ --------------------------------- 6.1/38.8 MB 2.9 MB/s eta 0:00:12
#    ------ --------------------------------- 6.1/38.8 MB 2.9 MB/s eta 0:00:12
#    ------ --------------------------------- 6.1/38.8 MB 2.8 MB/s eta 0:00:12
#    ------ --------------------------------- 6.1/38.8 MB 2.7 MB/s eta 0:00:12
#    ------ --------------------------------- 6.4/38.8 MB 2.8 MB/s eta 0:00:12
#    ------- -------------------------------- 7.0/38.8 MB 3.0 MB/s eta 0:00:11
#    -------- ------------------------------- 8.0/38.8 MB 3.3 MB/s eta 0:00:10
#    -------- ------------------------------- 8.3/38.8 MB 3.4 MB/s eta 0:00:09
#    -------- ------------------------------- 8.3/38.8 MB 3.4 MB/s eta 0:00:09
#    -------- ------------------------------- 8.3/38.8 MB 3.4 MB/s eta 0:00:09
#    -------- ------------------------------- 8.3/38.8 MB 3.4 MB/s eta 0:00:09
#    -------- ------------------------------- 8.3/38.8 MB 3.4 MB/s eta 0:00:09
#    -------- ------------------------------- 8.4/38.8 MB 3.1 MB/s eta 0:00:10
#    --------- ------------------------------ 8.8/38.8 MB 3.2 MB/s eta 0:00:10
#    --------- ------------------------------ 9.7/38.8 MB 3.5 MB/s eta 0:00:09
#    ---------- ----------------------------- 10.3/38.8 MB 3.7 MB/s eta 0:00:08
#    ---------- ----------------------------- 10.3/38.8 MB 3.7 MB/s eta 0:00:08
#    ---------- ----------------------------- 10.3/38.8 MB 3.7 MB/s eta 0:00:08
#    ---------- ----------------------------- 10.3/38.8 MB 3.7 MB/s eta 0:00:08
#    ---------- ----------------------------- 10.3/38.8 MB 3.7 MB/s eta 0:00:08
#    ---------- ----------------------------- 10.3/38.8 MB 3.4 MB/s eta 0:00:09
#    ---------- ----------------------------- 10.5/38.8 MB 3.4 MB/s eta 0:00:09
#    ----------- ---------------------------- 11.1/38.8 MB 3.6 MB/s eta 0:00:08
#    ------------ --------------------------- 11.9/38.8 MB 3.8 MB/s eta 0:00:08
#    ------------ --------------------------- 12.5/38.8 MB 4.0 MB/s eta 0:00:07
#    ------------- -------------------------- 12.7/38.8 MB 4.0 MB/s eta 0:00:07
#    ------------- -------------------------- 12.9/38.8 MB 4.0 MB/s eta 0:00:07
#    ------------- -------------------------- 13.1/38.8 MB 4.0 MB/s eta 0:00:07
#    ------------- -------------------------- 13.2/38.8 MB 4.0 MB/s eta 0:00:07
#    ------------- -------------------------- 13.3/38.8 MB 4.0 MB/s eta 0:00:07
#    ------------- -------------------------- 13.3/38.8 MB 3.9 MB/s eta 0:00:07
#    ------------- -------------------------- 13.4/38.8 MB 3.9 MB/s eta 0:00:07
#    -------------- ------------------------- 13.6/38.8 MB 3.8 MB/s eta 0:00:07
#    -------------- ------------------------- 13.7/38.8 MB 3.9 MB/s eta 0:00:07
#    -------------- ------------------------- 13.9/38.8 MB 3.9 MB/s eta 0:00:07
#    -------------- ------------------------- 14.1/38.8 MB 3.9 MB/s eta 0:00:07
#    -------------- ------------------------- 14.3/38.8 MB 3.9 MB/s eta 0:00:07
#    --------------- ------------------------ 14.6/38.8 MB 3.9 MB/s eta 0:00:07
#    --------------- ------------------------ 14.9/38.8 MB 3.9 MB/s eta 0:00:07
#    --------------- ------------------------ 15.2/38.8 MB 3.9 MB/s eta 0:00:06
#    ---------------- ----------------------- 15.5/38.8 MB 3.9 MB/s eta 0:00:06
#    ---------------- ----------------------- 15.8/38.8 MB 3.9 MB/s eta 0:00:06
#    ---------------- ----------------------- 16.2/38.8 MB 4.7 MB/s eta 0:00:05
#    ----------------- ---------------------- 16.6/38.8 MB 5.7 MB/s eta 0:00:04
#    ----------------- ---------------------- 16.9/38.8 MB 5.6 MB/s eta 0:00:04
#    ----------------- ---------------------- 17.4/38.8 MB 5.6 MB/s eta 0:00:04
#    ------------------ --------------------- 17.8/38.8 MB 5.5 MB/s eta 0:00:04
#    ------------------ --------------------- 18.3/38.8 MB 5.5 MB/s eta 0:00:04
#    ------------------- -------------------- 18.6/38.8 MB 6.2 MB/s eta 0:00:04
#    ------------------- -------------------- 18.9/38.8 MB 6.1 MB/s eta 0:00:04
#    ------------------- -------------------- 19.2/38.8 MB 6.0 MB/s eta 0:00:04
#    -------------------- ------------------- 19.4/38.8 MB 5.9 MB/s eta 0:00:04
#    -------------------- ------------------- 19.5/38.8 MB 5.7 MB/s eta 0:00:04
#    -------------------- ------------------- 19.7/38.8 MB 5.6 MB/s eta 0:00:04
#    -------------------- ------------------- 20.0/38.8 MB 5.5 MB/s eta 0:00:04
#    -------------------- ------------------- 20.2/38.8 MB 5.5 MB/s eta 0:00:04
#    --------------------- ------------------ 20.5/38.8 MB 5.4 MB/s eta 0:00:04
#    --------------------- ------------------ 20.8/38.8 MB 6.2 MB/s eta 0:00:03
#    --------------------- ------------------ 21.1/38.8 MB 6.1 MB/s eta 0:00:03
#    ---------------------- ----------------- 21.4/38.8 MB 6.0 MB/s eta 0:00:03
#    ---------------------- ----------------- 21.7/38.8 MB 6.0 MB/s eta 0:00:03
#    ---------------------- ----------------- 21.8/38.8 MB 5.7 MB/s eta 0:00:03
#    ---------------------- ----------------- 22.2/38.8 MB 5.7 MB/s eta 0:00:03
#    ----------------------- ---------------- 22.5/38.8 MB 5.6 MB/s eta 0:00:03
#    ----------------------- ---------------- 22.9/38.8 MB 5.6 MB/s eta 0:00:03
#    ----------------------- ---------------- 23.2/38.8 MB 5.7 MB/s eta 0:00:03
#    ------------------------ --------------- 23.5/38.8 MB 6.1 MB/s eta 0:00:03
#    ------------------------ --------------- 23.8/38.8 MB 6.4 MB/s eta 0:00:03
#    ------------------------ --------------- 24.1/38.8 MB 6.5 MB/s eta 0:00:03
#    ------------------------- -------------- 24.4/38.8 MB 6.5 MB/s eta 0:00:03
#    ------------------------- -------------- 24.7/38.8 MB 6.6 MB/s eta 0:00:03
#    ------------------------- -------------- 24.9/38.8 MB 6.5 MB/s eta 0:00:03
#    ------------------------- -------------- 25.1/38.8 MB 6.5 MB/s eta 0:00:03
#    -------------------------- ------------- 25.4/38.8 MB 6.5 MB/s eta 0:00:03
#    -------------------------- ------------- 25.7/38.8 MB 6.5 MB/s eta 0:00:03
#    -------------------------- ------------- 25.9/38.8 MB 6.4 MB/s eta 0:00:03
#    --------------------------- ------------ 26.2/38.8 MB 6.4 MB/s eta 0:00:02
#    --------------------------- ------------ 26.3/38.8 MB 6.3 MB/s eta 0:00:02
#    --------------------------- ------------ 26.6/38.8 MB 6.2 MB/s eta 0:00:02
#    --------------------------- ------------ 26.8/38.8 MB 6.1 MB/s eta 0:00:02
#    --------------------------- ------------ 27.0/38.8 MB 6.1 MB/s eta 0:00:02
#    ---------------------------- ----------- 27.2/38.8 MB 6.0 MB/s eta 0:00:02
#    ---------------------------- ----------- 27.6/38.8 MB 6.0 MB/s eta 0:00:02
#    ---------------------------- ----------- 27.8/38.8 MB 5.9 MB/s eta 0:00:02
#    ----------------------------- ---------- 28.2/38.8 MB 5.8 MB/s eta 0:00:02
#    ----------------------------- ---------- 28.5/38.8 MB 5.9 MB/s eta 0:00:02
#    ----------------------------- ---------- 28.9/38.8 MB 5.9 MB/s eta 0:00:02
#    ------------------------------ --------- 29.2/38.8 MB 5.9 MB/s eta 0:00:02
#    ------------------------------ --------- 29.6/38.8 MB 6.0 MB/s eta 0:00:02
#    ------------------------------- -------- 30.1/38.8 MB 6.2 MB/s eta 0:00:02
#    ------------------------------- -------- 30.4/38.8 MB 6.4 MB/s eta 0:00:02
#    ------------------------------- -------- 30.8/38.8 MB 6.4 MB/s eta 0:00:02
#    ------------------------------- -------- 31.0/38.8 MB 6.3 MB/s eta 0:00:02
#    -------------------------------- ------- 31.1/38.8 MB 6.2 MB/s eta 0:00:02
#    -------------------------------- ------- 31.2/38.8 MB 6.1 MB/s eta 0:00:02
#    -------------------------------- ------- 31.3/38.8 MB 6.0 MB/s eta 0:00:02
#    -------------------------------- ------- 31.4/38.8 MB 5.9 MB/s eta 0:00:02
#    -------------------------------- ------- 31.5/38.8 MB 5.8 MB/s eta 0:00:02
#    -------------------------------- ------- 31.7/38.8 MB 5.7 MB/s eta 0:00:02
#    -------------------------------- ------- 31.9/38.8 MB 5.6 MB/s eta 0:00:02
#    --------------------------------- ------ 32.1/38.8 MB 5.7 MB/s eta 0:00:02
#    --------------------------------- ------ 32.3/38.8 MB 5.6 MB/s eta 0:00:02
#    --------------------------------- ------ 32.6/38.8 MB 5.6 MB/s eta 0:00:02
#    --------------------------------- ------ 32.9/38.8 MB 5.6 MB/s eta 0:00:02
#    ---------------------------------- ----- 33.2/38.8 MB 5.6 MB/s eta 0:00:01
#    ---------------------------------- ----- 33.5/38.8 MB 5.6 MB/s eta 0:00:01
#    ---------------------------------- ----- 33.9/38.8 MB 5.6 MB/s eta 0:00:01
#    ----------------------------------- ---- 34.2/38.8 MB 5.6 MB/s eta 0:00:01
#    ----------------------------------- ---- 34.6/38.8 MB 5.7 MB/s eta 0:00:01
#    ------------------------------------ --- 35.0/38.8 MB 5.7 MB/s eta 0:00:01
#    ------------------------------------ --- 35.4/38.8 MB 5.8 MB/s eta 0:00:01
#    ------------------------------------ --- 35.8/38.8 MB 6.0 MB/s eta 0:00:01
#    ------------------------------------- -- 36.2/38.8 MB 6.1 MB/s eta 0:00:01
#    ------------------------------------- -- 36.7/38.8 MB 6.2 MB/s eta 0:00:01
#    -------------------------------------- - 37.1/38.8 MB 6.5 MB/s eta 0:00:01
#    -------------------------------------- - 37.3/38.8 MB 6.4 MB/s eta 0:00:01
#    -------------------------------------- - 37.5/38.8 MB 6.4 MB/s eta 0:00:01
#    -------------------------------------- - 37.7/38.8 MB 6.4 MB/s eta 0:00:01
#    -------------------------------------- - 37.8/38.8 MB 6.2 MB/s eta 0:00:01
#    ---------------------------------------  37.9/38.8 MB 6.0 MB/s eta 0:00:01
#    ---------------------------------------  38.0/38.8 MB 6.0 MB/s eta 0:00:01
#    ---------------------------------------  38.1/38.8 MB 5.9 MB/s eta 0:00:01
#    ---------------------------------------  38.3/38.8 MB 5.8 MB/s eta 0:00:01
#    ---------------------------------------  38.6/38.8 MB 5.7 MB/s eta 0:00:01
#    ---------------------------------------  38.7/38.8 MB 5.7 MB/s eta 0:00:01
#    ---------------------------------------  38.7/38.8 MB 5.7 MB/s eta 0:00:01
#    ---------------------------------------- 38.8/38.8 MB 5.5 MB/s eta 0:00:00
# Downloading sahi-0.11.16-py3-none-any.whl (112 kB)
#    ---------------------------------------- 0.0/112.6 kB ? eta -:--:--
#    ---------------------------------------- 112.6/112.6 kB 3.3 MB/s eta 0:00:00
# Downloading pybboxes-0.1.6-py3-none-any.whl (24 kB)
# Downloading opencv_python-4.8.1.78-cp37-abi3-win_amd64.whl (38.1 MB)
#    ---------------------------------------- 0.0/38.1 MB ? eta -:--:--
#    ---------------------------------------- 0.3/38.1 MB 8.3 MB/s eta 0:00:05
#     --------------------------------------- 0.6/38.1 MB 7.1 MB/s eta 0:00:06
#     --------------------------------------- 0.9/38.1 MB 7.0 MB/s eta 0:00:06
#    - -------------------------------------- 1.2/38.1 MB 7.2 MB/s eta 0:00:06
#    - -------------------------------------- 1.6/38.1 MB 7.4 MB/s eta 0:00:05
#    -- ------------------------------------- 2.0/38.1 MB 7.5 MB/s eta 0:00:05
#    -- ------------------------------------- 2.4/38.1 MB 7.5 MB/s eta 0:00:05
#    -- ------------------------------------- 2.8/38.1 MB 7.8 MB/s eta 0:00:05
#    --- ------------------------------------ 3.3/38.1 MB 8.0 MB/s eta 0:00:05
#    --- ------------------------------------ 3.7/38.1 MB 8.2 MB/s eta 0:00:05
#    ---- ----------------------------------- 4.1/38.1 MB 8.3 MB/s eta 0:00:05
#    ---- ----------------------------------- 4.4/38.1 MB 8.0 MB/s eta 0:00:05
#    ---- ----------------------------------- 4.6/38.1 MB 7.7 MB/s eta 0:00:05
#    ---- ----------------------------------- 4.7/38.1 MB 7.3 MB/s eta 0:00:05
#    ----- ---------------------------------- 4.9/38.1 MB 7.1 MB/s eta 0:00:05
#    ----- ---------------------------------- 5.0/38.1 MB 6.8 MB/s eta 0:00:05
#    ----- ---------------------------------- 5.2/38.1 MB 6.7 MB/s eta 0:00:05
#    ----- ---------------------------------- 5.5/38.1 MB 6.6 MB/s eta 0:00:05
#    ----- ---------------------------------- 5.7/38.1 MB 6.5 MB/s eta 0:00:05
#    ------ --------------------------------- 6.0/38.1 MB 6.5 MB/s eta 0:00:05
#    ------ --------------------------------- 6.3/38.1 MB 6.5 MB/s eta 0:00:05
#    ------ --------------------------------- 6.6/38.1 MB 6.5 MB/s eta 0:00:05
#    ------- -------------------------------- 7.0/38.1 MB 6.5 MB/s eta 0:00:05
#    ------- -------------------------------- 7.3/38.1 MB 6.6 MB/s eta 0:00:05
#    -------- ------------------------------- 7.6/38.1 MB 6.6 MB/s eta 0:00:05
#    -------- ------------------------------- 7.9/38.1 MB 6.6 MB/s eta 0:00:05
#    -------- ------------------------------- 8.4/38.1 MB 6.8 MB/s eta 0:00:05
#    --------- ------------------------------ 8.8/38.1 MB 6.9 MB/s eta 0:00:05
#    --------- ------------------------------ 9.2/38.1 MB 7.0 MB/s eta 0:00:05
#    ---------- ----------------------------- 9.6/38.1 MB 7.0 MB/s eta 0:00:05
#    ---------- ----------------------------- 9.7/38.1 MB 7.0 MB/s eta 0:00:05
#    ---------- ----------------------------- 9.8/38.1 MB 6.7 MB/s eta 0:00:05
#    ---------- ----------------------------- 10.0/38.1 MB 6.6 MB/s eta 0:00:05
#    ---------- ----------------------------- 10.2/38.1 MB 6.5 MB/s eta 0:00:05
#    ---------- ----------------------------- 10.4/38.1 MB 6.5 MB/s eta 0:00:05
#    ----------- ---------------------------- 10.7/38.1 MB 6.4 MB/s eta 0:00:05
#    ----------- ---------------------------- 11.0/38.1 MB 6.4 MB/s eta 0:00:05
#    ----------- ---------------------------- 11.3/38.1 MB 6.4 MB/s eta 0:00:05
#    ------------ --------------------------- 11.6/38.1 MB 6.4 MB/s eta 0:00:05
#    ------------ --------------------------- 11.9/38.1 MB 6.4 MB/s eta 0:00:05
#    ------------ --------------------------- 12.2/38.1 MB 6.3 MB/s eta 0:00:05
#    ------------- -------------------------- 12.5/38.1 MB 6.3 MB/s eta 0:00:05
#    ------------- -------------------------- 12.9/38.1 MB 6.2 MB/s eta 0:00:05
#    ------------- -------------------------- 13.1/38.1 MB 6.2 MB/s eta 0:00:04
#    -------------- ------------------------- 13.4/38.1 MB 6.1 MB/s eta 0:00:05
#    -------------- ------------------------- 13.6/38.1 MB 6.1 MB/s eta 0:00:05
#    -------------- ------------------------- 14.0/38.1 MB 6.0 MB/s eta 0:00:05
#    -------------- ------------------------- 14.2/38.1 MB 6.0 MB/s eta 0:00:05
#    --------------- ------------------------ 14.5/38.1 MB 5.9 MB/s eta 0:00:05
#    --------------- ------------------------ 14.7/38.1 MB 5.9 MB/s eta 0:00:04
#    --------------- ------------------------ 15.0/38.1 MB 6.0 MB/s eta 0:00:04
#    ---------------- ----------------------- 15.3/38.1 MB 6.2 MB/s eta 0:00:04
#    ---------------- ----------------------- 15.5/38.1 MB 6.2 MB/s eta 0:00:04
#    ---------------- ----------------------- 15.7/38.1 MB 6.2 MB/s eta 0:00:04
#    ---------------- ----------------------- 16.0/38.1 MB 6.2 MB/s eta 0:00:04
#    ----------------- ---------------------- 16.3/38.1 MB 6.2 MB/s eta 0:00:04
#    ----------------- ---------------------- 16.6/38.1 MB 6.2 MB/s eta 0:00:04
#    ----------------- ---------------------- 17.0/38.1 MB 6.2 MB/s eta 0:00:04
#    ------------------ --------------------- 17.4/38.1 MB 6.3 MB/s eta 0:00:04
#    ------------------ --------------------- 17.8/38.1 MB 6.3 MB/s eta 0:00:04
#    ------------------- -------------------- 18.1/38.1 MB 6.3 MB/s eta 0:00:04
#    ------------------- -------------------- 18.2/38.1 MB 6.2 MB/s eta 0:00:04
#    ------------------- -------------------- 18.4/38.1 MB 6.1 MB/s eta 0:00:04
#    ------------------- -------------------- 18.7/38.1 MB 6.1 MB/s eta 0:00:04
#    ------------------- -------------------- 18.9/38.1 MB 6.0 MB/s eta 0:00:04
#    -------------------- ------------------- 19.3/38.1 MB 6.0 MB/s eta 0:00:04
#    -------------------- ------------------- 19.6/38.1 MB 5.9 MB/s eta 0:00:04
#    -------------------- ------------------- 19.9/38.1 MB 5.9 MB/s eta 0:00:04
#    --------------------- ------------------ 20.2/38.1 MB 6.1 MB/s eta 0:00:03
#    --------------------- ------------------ 20.4/38.1 MB 6.2 MB/s eta 0:00:03
#    --------------------- ------------------ 20.6/38.1 MB 6.2 MB/s eta 0:00:03
#    --------------------- ------------------ 20.9/38.1 MB 6.1 MB/s eta 0:00:03
#    ---------------------- ----------------- 21.2/38.1 MB 6.2 MB/s eta 0:00:03
#    ---------------------- ----------------- 21.5/38.1 MB 6.1 MB/s eta 0:00:03
#    ---------------------- ----------------- 21.8/38.1 MB 6.2 MB/s eta 0:00:03
#    ----------------------- ---------------- 22.0/38.1 MB 6.1 MB/s eta 0:00:03
#    ----------------------- ---------------- 22.0/38.1 MB 6.1 MB/s eta 0:00:03
#    ----------------------- ---------------- 22.0/38.1 MB 5.7 MB/s eta 0:00:03
#    ----------------------- ---------------- 22.4/38.1 MB 5.8 MB/s eta 0:00:03
#    ----------------------- ---------------- 22.8/38.1 MB 5.8 MB/s eta 0:00:03
#    ------------------------ --------------- 23.3/38.1 MB 5.9 MB/s eta 0:00:03
#    ------------------------ --------------- 23.7/38.1 MB 6.0 MB/s eta 0:00:03
#    ------------------------- -------------- 24.0/38.1 MB 6.1 MB/s eta 0:00:03
#    ------------------------- -------------- 24.5/38.1 MB 6.2 MB/s eta 0:00:03
#    -------------------------- ------------- 24.9/38.1 MB 6.3 MB/s eta 0:00:03
#    -------------------------- ------------- 25.2/38.1 MB 6.4 MB/s eta 0:00:03
#    -------------------------- ------------- 25.5/38.1 MB 6.4 MB/s eta 0:00:02
#    -------------------------- ------------- 25.6/38.1 MB 6.3 MB/s eta 0:00:02
#    --------------------------- ------------ 25.9/38.1 MB 6.2 MB/s eta 0:00:02
#    --------------------------- ------------ 26.0/38.1 MB 6.2 MB/s eta 0:00:02
#    --------------------------- ------------ 26.1/38.1 MB 6.1 MB/s eta 0:00:02
#    --------------------------- ------------ 26.3/38.1 MB 6.0 MB/s eta 0:00:02
#    --------------------------- ------------ 26.5/38.1 MB 6.0 MB/s eta 0:00:02
#    ---------------------------- ----------- 26.7/38.1 MB 5.9 MB/s eta 0:00:02
#    ---------------------------- ----------- 26.9/38.1 MB 5.8 MB/s eta 0:00:02
#    ---------------------------- ----------- 27.2/38.1 MB 5.8 MB/s eta 0:00:02
#    ---------------------------- ----------- 27.5/38.1 MB 5.8 MB/s eta 0:00:02
#    ----------------------------- ---------- 27.7/38.1 MB 5.7 MB/s eta 0:00:02
#    ----------------------------- ---------- 27.8/38.1 MB 5.6 MB/s eta 0:00:02
#    ----------------------------- ---------- 27.9/38.1 MB 5.6 MB/s eta 0:00:02
#    ----------------------------- ---------- 28.2/38.1 MB 5.6 MB/s eta 0:00:02
#    ----------------------------- ---------- 28.5/38.1 MB 5.6 MB/s eta 0:00:02
#    ------------------------------ --------- 28.9/38.1 MB 5.7 MB/s eta 0:00:02
#    ------------------------------ --------- 29.2/38.1 MB 5.7 MB/s eta 0:00:02
#    ------------------------------- -------- 29.6/38.1 MB 5.7 MB/s eta 0:00:02
#    ------------------------------- -------- 30.0/38.1 MB 5.8 MB/s eta 0:00:02
#    -------------------------------- ------- 30.5/38.1 MB 6.0 MB/s eta 0:00:02
#    -------------------------------- ------- 31.0/38.1 MB 6.1 MB/s eta 0:00:02
#    --------------------------------- ------ 31.5/38.1 MB 6.2 MB/s eta 0:00:02
#    --------------------------------- ------ 31.8/38.1 MB 6.2 MB/s eta 0:00:02
#    --------------------------------- ------ 32.0/38.1 MB 6.1 MB/s eta 0:00:01
#    --------------------------------- ------ 32.3/38.1 MB 6.5 MB/s eta 0:00:01
#    ---------------------------------- ----- 32.6/38.1 MB 6.5 MB/s eta 0:00:01
#    ---------------------------------- ----- 32.8/38.1 MB 6.4 MB/s eta 0:00:01
#    ---------------------------------- ----- 33.0/38.1 MB 6.4 MB/s eta 0:00:01
#    ---------------------------------- ----- 33.3/38.1 MB 6.2 MB/s eta 0:00:01
#    ----------------------------------- ---- 33.5/38.1 MB 6.2 MB/s eta 0:00:01
#    ----------------------------------- ---- 33.6/38.1 MB 6.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 33.8/38.1 MB 6.0 MB/s eta 0:00:01
#    ----------------------------------- ---- 34.1/38.1 MB 5.9 MB/s eta 0:00:01
#    ------------------------------------ --- 34.3/38.1 MB 5.8 MB/s eta 0:00:01
#    ------------------------------------ --- 34.5/38.1 MB 5.7 MB/s eta 0:00:01
#    ------------------------------------ --- 34.8/38.1 MB 5.7 MB/s eta 0:00:01
#    ------------------------------------ --- 35.1/38.1 MB 5.6 MB/s eta 0:00:01
#    ------------------------------------- -- 35.5/38.1 MB 5.7 MB/s eta 0:00:01
#    ------------------------------------- -- 35.9/38.1 MB 5.8 MB/s eta 0:00:01
#    -------------------------------------- - 36.2/38.1 MB 6.0 MB/s eta 0:00:01
#    -------------------------------------- - 36.6/38.1 MB 6.2 MB/s eta 0:00:01
#    -------------------------------------- - 36.9/38.1 MB 6.3 MB/s eta 0:00:01
#    ---------------------------------------  37.2/38.1 MB 6.4 MB/s eta 0:00:01
#    ---------------------------------------  37.4/38.1 MB 6.4 MB/s eta 0:00:01
#    ---------------------------------------  37.7/38.1 MB 6.3 MB/s eta 0:00:01
#    ---------------------------------------  38.0/38.1 MB 6.5 MB/s eta 0:00:01
#    ---------------------------------------  38.1/38.1 MB 6.5 MB/s eta 0:00:01
#    ---------------------------------------  38.1/38.1 MB 6.5 MB/s eta 0:00:01
#    ---------------------------------------- 38.1/38.1 MB 6.1 MB/s eta 0:00:00
# Downloading thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# Downloading botocore-1.34.139-py3-none-any.whl (12.4 MB)
#    ---------------------------------------- 0.0/12.4 MB ? eta -:--:--
#    - -------------------------------------- 0.4/12.4 MB 7.6 MB/s eta 0:00:02
#    -- ------------------------------------- 0.7/12.4 MB 7.7 MB/s eta 0:00:02
#    --- ------------------------------------ 1.1/12.4 MB 7.9 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.6/12.4 MB 8.4 MB/s eta 0:00:02
#    ------ --------------------------------- 2.0/12.4 MB 8.3 MB/s eta 0:00:02
#    ------- -------------------------------- 2.4/12.4 MB 8.6 MB/s eta 0:00:02
#    --------- ------------------------------ 2.8/12.4 MB 8.6 MB/s eta 0:00:02
#    --------- ------------------------------ 3.1/12.4 MB 8.1 MB/s eta 0:00:02
#    ---------- ----------------------------- 3.3/12.4 MB 7.7 MB/s eta 0:00:02
#    ----------- ---------------------------- 3.5/12.4 MB 7.4 MB/s eta 0:00:02
#    ----------- ---------------------------- 3.7/12.4 MB 7.1 MB/s eta 0:00:02
#    ------------ --------------------------- 3.9/12.4 MB 7.0 MB/s eta 0:00:02
#    ------------- -------------------------- 4.2/12.4 MB 6.9 MB/s eta 0:00:02
#    -------------- ------------------------- 4.6/12.4 MB 6.9 MB/s eta 0:00:02
#    --------------- ------------------------ 4.9/12.4 MB 7.0 MB/s eta 0:00:02
#    ----------------- ---------------------- 5.3/12.4 MB 7.0 MB/s eta 0:00:02
#    ------------------ --------------------- 5.6/12.4 MB 7.1 MB/s eta 0:00:01
#    ------------------- -------------------- 6.1/12.4 MB 7.3 MB/s eta 0:00:01
#    -------------------- ------------------- 6.3/12.4 MB 7.2 MB/s eta 0:00:01
#    --------------------- ------------------ 6.5/12.4 MB 7.0 MB/s eta 0:00:01
#    --------------------- ------------------ 6.6/12.4 MB 6.8 MB/s eta 0:00:01
#    --------------------- ------------------ 6.8/12.4 MB 6.7 MB/s eta 0:00:01
#    ---------------------- ----------------- 7.0/12.4 MB 6.5 MB/s eta 0:00:01
#    ----------------------- ---------------- 7.2/12.4 MB 6.5 MB/s eta 0:00:01
#    ------------------------ --------------- 7.4/12.4 MB 6.4 MB/s eta 0:00:01
#    ------------------------ --------------- 7.7/12.4 MB 6.4 MB/s eta 0:00:01
#    ------------------------- -------------- 8.0/12.4 MB 6.4 MB/s eta 0:00:01
#    -------------------------- ------------- 8.3/12.4 MB 6.4 MB/s eta 0:00:01
#    --------------------------- ------------ 8.6/12.4 MB 6.4 MB/s eta 0:00:01
#    ----------------------------- ---------- 9.0/12.4 MB 6.4 MB/s eta 0:00:01
#    ------------------------------ --------- 9.4/12.4 MB 6.5 MB/s eta 0:00:01
#    ------------------------------- -------- 9.8/12.4 MB 6.6 MB/s eta 0:00:01
#    -------------------------------- ------- 10.1/12.4 MB 6.6 MB/s eta 0:00:01
#    --------------------------------- ------ 10.3/12.4 MB 6.5 MB/s eta 0:00:01
#    ---------------------------------- ----- 10.6/12.4 MB 6.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 10.9/12.4 MB 6.4 MB/s eta 0:00:01
#    ------------------------------------ --- 11.2/12.4 MB 6.4 MB/s eta 0:00:01
#    ------------------------------------- -- 11.4/12.4 MB 6.4 MB/s eta 0:00:01
#    ------------------------------------- -- 11.7/12.4 MB 6.3 MB/s eta 0:00:01
#    -------------------------------------- - 11.9/12.4 MB 6.2 MB/s eta 0:00:01
#    ---------------------------------------  12.2/12.4 MB 6.2 MB/s eta 0:00:01
#    ---------------------------------------  12.3/12.4 MB 6.2 MB/s eta 0:00:01
#    ---------------------------------------- 12.4/12.4 MB 6.0 MB/s eta 0:00:00
# Using cached gitdb-4.0.11-py3-none-any.whl (62 kB)
# Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Downloading s3transfer-0.10.2-py3-none-any.whl (82 kB)
#    ---------------------------------------- 0.0/82.7 kB ? eta -:--:--
#    ---------------------------------------- 82.7/82.7 kB 4.5 MB/s eta 0:00:00
# Downloading shapely-2.0.4-cp310-cp310-win_amd64.whl (1.4 MB)
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ------------ --------------------------- 0.5/1.4 MB 9.4 MB/s eta 0:00:01
#    ----------------------- ---------------- 0.8/1.4 MB 8.9 MB/s eta 0:00:01
#    -------------------------------- ------- 1.2/1.4 MB 8.3 MB/s eta 0:00:01
#    ---------------------------------------- 1.4/1.4 MB 7.6 MB/s eta 0:00:00
# Using cached click-8.1.7-py3-none-any.whl (97 kB)
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Downloading python_magic-0.4.27-py2.py3-none-any.whl (13 kB)
# Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
#    ---------------------------------------- 0.0/54.5 kB ? eta -:--:--
#    ---------------------------------------- 54.5/54.5 kB 2.8 MB/s eta 0:00:00
# Downloading terminaltables-3.1.10-py2.py3-none-any.whl (15 kB)
# Using cached smmap-5.0.1-py3-none-any.whl (24 kB)
# Building wheels for collected packages: fire
#   Building wheel for fire (setup.py): started
#   Building wheel for fire (setup.py): finished with status 'done'
#   Created wheel for fire: filename=fire-0.6.0-py2.py3-none-any.whl size=117048 sha256=cad286cf48d5d965182a08c8323a97c95589a1c95f88b254ad367e59645b1cbb
#   Stored in directory: c:\users\sushant mittal\appdata\local\pip\cache\wheels\d6\6d\5d\5b73fa0f46d01a793713f8859201361e9e581ced8c75e5c6a3
# Successfully built fire
# Installing collected packages: terminaltables, smmap, shapely, python-magic, python-dotenv, pybboxes, opencv-python-headless, opencv-python, jmespath, idna, fire, click, chardet, gitdb, botocore, thop, sahi, s3transfer, requests-toolbelt, gitpython, roboflow, boto3, yolov5
#   Attempting uninstall: opencv-python
#     Found existing installation: opencv-python 4.10.0.84
#     Uninstalling opencv-python-4.10.0.84:
#       Successfully uninstalled opencv-python-4.10.0.84
#   Attempting uninstall: idna
#     Found existing installation: idna 3.4
#     Uninstalling idna-3.4:
#       Successfully uninstalled idna-3.4
# Successfully installed boto3-1.34.139 botocore-1.34.139 chardet-4.0.0 click-8.1.7 fire-0.6.0 gitdb-4.0.11 gitpython-3.1.43 idna-3.7 jmespath-1.0.1 opencv-python-4.8.1.78 opencv-python-headless-4.10.0.84 pybboxes-0.1.6 python-dotenv-1.0.1 python-magic-0.4.27 requests-toolbelt-1.0.0 roboflow-1.1.34 s3transfer-0.10.2 sahi-0.11.16 shapely-2.0.4 smmap-5.0.1 terminaltables-3.1.10 thop-0.1.1.post2209072238 yolov5-7.0.13
# Note: you may need to restart the kernel to use updated packages.

# %%
# Load the YOLOv5 model from Torch Hub
yolo_model = torch.hub.load('ultralytics/yolov5', 'yolov5s', pretrained=True)

# Extract the backbone (CSPDarknet53) from YOLOv5
backbone = nn.Sequential(*list(yolo_model.model.children())[:-1])

# Function to calculate the output size of the backbone
def get_backbone_output_size(backbone, input_size):
    with torch.no_grad():
        dummy_input = torch.zeros(1, 3, *input_size)
        output = backbone(dummy_input)
    return output.view(1, -1).size(1)

# Calculate the size of the features coming out of the backbone
input_size = (224,224)
backbone_output_size = get_backbone_output_size(backbone, input_size)

# Define a new classification head
class YOLOv5Classification(nn.Module):
    def __init__(self, backbone, backbone_output_size, num_classes):
        super(YOLOv5Classification, self).__init__()
        self.backbone = backbone
        self.classifier = nn.Sequential(
            nn.Flatten(),
            nn.Linear(backbone_output_size, 256),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(256, num_classes)
        )

    def forward(self, x):
        x = self.backbone(x)
        x = self.classifier(x)
        return x

# Instantiate the modified model
model = YOLOv5Classification(backbone, backbone_output_size, num_classes=4)

# Move the model to GPU if available
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = model.to(device)
# Out:
# Using cache found in C:\Users\sushant mittal/.cache\torch\hub\ultralytics_yolov5_master
# YOLOv5  2024-7-5 Python-3.10.13 torch-2.3.1+cu118 CUDA:0 (NVIDIA GeForce RTX 3050 Ti Laptop GPU, 4096MiB)
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# Adding AutoShape...

# %%
from torch.optim import Adam
from torch.nn import CrossEntropyLoss
from sklearn.metrics import accuracy_score

# Define loss function and optimizer
criterion = CrossEntropyLoss()
optimizer = Adam(model.parameters(), lr=0.001)

# Training function
def train_model(model, train_loader, val_loader, criterion, optimizer, device, epochs=25):
    for epoch in range(epochs):
        model.train()
        train_loss = 0
        train_acc = 0
        for images, labels in train_loader:
            images, labels = images.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            train_loss += loss.item()
            _, preds = torch.max(outputs, 1)
            train_acc += accuracy_score(labels.cpu(), preds.cpu())
        train_loss /= len(train_loader)
        train_acc /= len(train_loader)

        # Validation
        model.eval()
        val_loss = 0
        val_acc = 0
        with torch.no_grad():
            for images, labels in val_loader:
                images, labels = images.to(device), labels.to(device)
                outputs = model(images)
                loss = criterion(outputs, labels)
                val_loss += loss.item()
                _, preds = torch.max(outputs, 1)
                val_acc += accuracy_score(labels.cpu(), preds.cpu())
        val_loss /= len(val_loader)
        val_acc /= len(val_loader)

        print(f'Epoch {epoch+1}/{epochs}, Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.4f}, Val Loss: {val_loss:.4f}, Val Acc: {val_acc:.4f}')

# Train the model
train_model(model, train_loader, val_loader, criterion, optimizer, device)
# Out:
# Epoch 1/25, Train Loss: 3.4072, Train Acc: 0.2825, Val Loss: 1.3780, Val Acc: 0.2819
# Epoch 2/25, Train Loss: 1.4084, Train Acc: 0.2823, Val Loss: 1.3769, Val Acc: 0.2819
# Epoch 3/25, Train Loss: 1.3762, Train Acc: 0.2823, Val Loss: 1.3771, Val Acc: 0.2819
# Epoch 4/25, Train Loss: 1.3760, Train Acc: 0.2824, Val Loss: 1.3770, Val Acc: 0.2819
# Epoch 5/25, Train Loss: 1.3761, Train Acc: 0.2822, Val Loss: 1.3770, Val Acc: 0.2819
# Epoch 6/25, Train Loss: 1.3760, Train Acc: 0.2823, Val Loss: 1.3770, Val Acc: 0.2819
# Epoch 7/25, Train Loss: 1.3760, Train Acc: 0.2823, Val Loss: 1.3769, Val Acc: 0.2819
# Epoch 8/25, Train Loss: 1.3760, Train Acc: 0.2824, Val Loss: 1.3771, Val Acc: 0.2819
# Epoch 9/25, Train Loss: 1.3760, Train Acc: 0.2822, Val Loss: 1.3770, Val Acc: 0.2819
# Epoch 10/25, Train Loss: 1.3760, Train Acc: 0.2823, Val Loss: 1.3769, Val Acc: 0.2819
# Epoch 11/25, Train Loss: 1.3760, Train Acc: 0.2823, Val Loss: 1.3768, Val Acc: 0.2819
# Epoch 12/25, Train Loss: 1.3760, Train Acc: 0.2824, Val Loss: 1.3772, Val Acc: 0.2819
# Epoch 13/25, Train Loss: 1.3760, Train Acc: 0.2823, Val Loss: 1.3770, Val Acc: 0.2819
# Epoch 14/25, Train Loss: 1.3760, Train Acc: 0.2823, Val Loss: 1.3770, Val Acc: 0.2819
# Epoch 15/25, Train Loss: 1.3760, Train Acc: 0.2823, Val Loss: 1.3769, Val Acc: 0.2819
# Epoch 16/25, Train Loss: 1.3761, Train Acc: 0.2823, Val Loss: 1.3771, Val Acc: 0.2819
# Epoch 17/25, Train Loss: 1.3760, Train Acc: 0.2823, Val Loss: 1.3770, Val Acc: 0.2819
# Epoch 18/25, Train Loss: 1.3760, Train Acc: 0.2823, Val Loss: 1.3771, Val Acc: 0.2819
# Epoch 19/25, Train Loss: 1.3760, Train Acc: 0.2823, Val Loss: 1.3770, Val Acc: 0.2819
# Epoch 20/25, Train Loss: 1.3760, Train Acc: 0.2824, Val Loss: 1.3769, Val Acc: 0.2819
# Epoch 21/25, Train Loss: 1.3760, Train Acc: 0.2823, Val Loss: 1.3771, Val Acc: 0.2819
# Epoch 22/25, Train Loss: 1.3760, Train Acc: 0.2823, Val Loss: 1.3772, Val Acc: 0.2819
# Epoch 23/25, Train Loss: 1.3760, Train Acc: 0.2823, Val Loss: 1.3771, Val Acc: 0.2819
# Epoch 24/25, Train Loss: 1.3760, Train Acc: 0.2822, Val Loss: 1.3769, Val Acc: 0.2819
# Epoch 25/25, Train Loss: 1.3760, Train Acc: 0.2823, Val Loss: 1.3769, Val Acc: 0.2819

# %%
# Testing function
def test_model(model, test_loader, device):
    model.eval()
    test_acc = 0
    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            _, preds = torch.max(outputs, 1)
            test_acc += accuracy_score(labels.cpu(), preds.cpu())
    test_acc /= len(test_loader)
    print(f'Test Accuracy: {test_acc:.4f}')

# Evaluate the model
test_model(model, test_loader, device)
# Out:
# Test Accuracy: 0.2847

# %%
# Save the entire model
torch.save(model, 'yolov5_classification_model.pth')

# %%
# Save only the model's state dictionary
torch.save(model.state_dict(), 'yolov5_classification_model_state_dict.pth')

# %%
# Load the entire model
model = torch.load('yolov5_classification_model.pth')
model = model.to(device)

# %%
# Testing function
def test_model(model, test_loader, device):
    model.eval()
    test_acc = 0
    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            _, preds = torch.max(outputs, 1)
            test_acc += accuracy_score(labels.cpu(), preds.cpu())
    test_acc /= len(test_loader)
    print(f'Test Accuracy: {test_acc:.4f}')

# Evaluate the model
test_model(model, test_loader, device)
# Out:
# Test Accuracy: 0.2847
